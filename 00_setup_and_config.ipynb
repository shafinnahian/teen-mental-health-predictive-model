# %% [markdown]
# <a href="https://colab.research.google.com/github/shafinnahian/teen-mental-health-predictive-model/blob/main/00_setup_and_config.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import annotations

import os
import sys
from pathlib import Path
from typing import Optional

_colab_root = Path("/content/teen-mental-health-predictive-model")
if _colab_root.is_dir():
    os.chdir(_colab_root)


def find_project_root(start: Optional[Path] = None) -> Path:
    """Walk upward until requirements.txt and src/config.py are found."""
    current = (start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "requirements.txt").exists() and (candidate / "src" / "config.py").exists():
            return candidate
    raise FileNotFoundError(
        "Could not locate project root. "
        "Expected a directory containing requirements.txt and src/config.py."
    )


PROJECT_ROOT = find_project_root()
print("Project root:", PROJECT_ROOT)

# %pip install -q -r {PROJECT_ROOT / "requirements.txt"}
# Out:
# Project root: /content/teen-mental-health-predictive-model

# %%
SRC_PATH = PROJECT_ROOT / "src"
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

import config
import paths
import data_loader
import io_utils

print("Imports OK:", [config.__name__, paths.__name__, data_loader.__name__, io_utils.__name__])
print("src on sys.path:", SRC_PATH)
# Out:
# Imports OK: ['config', 'paths', 'data_loader', 'io_utils']
# src on sys.path: /content/teen-mental-health-predictive-model/src

# %%
from paths import (
    ensure_output_dirs,
    data_csv_path,
    figures_dir,
    models_dir,
    metrics_dir,
    get_project_root,
)

ensure_output_dirs()
print("PROJECT_ROOT (paths.py):", get_project_root())
print("data CSV:", data_csv_path())
print("figures:", figures_dir())
print("models:", models_dir())
print("metrics:", metrics_dir())
# Out:
# PROJECT_ROOT (paths.py): /content/teen-mental-health-predictive-model
# data CSV: /content/teen-mental-health-predictive-model/data/Teen_Mental_Health.csv
# figures: /content/teen-mental-health-predictive-model/outputs/figures
# models: /content/teen-mental-health-predictive-model/outputs/models
# metrics: /content/teen-mental-health-predictive-model/outputs/metrics

# %%
from data_loader import load_raw_data, validate_data

df = load_raw_data()
validation = validate_data(df)
display(df.head())
validation
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9       Facebook          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4        YouTube          6.9
# 4   15  female                       4.7  All Platforms          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# 0                      low             2              2                1
# 1                     high             8              1               10
# 2                     high             2              4                2
# 3                   medium             1              7                9
# 4                   medium             3              5                2
#
#    depression_label  mental_health_risk_score sleep_quality  \
# 0                 0                         5          Fair
# 1                 0                        19          Good
# 2                 0                         8          Fair
# 3                 0                        17          Fair
# 4                 0                        10          Poor
#
#   digital_wellbeing_flag
# 0                At Risk
# 1               Moderate
# 2                Healthy
# 3               Moderate
# 4               Moderate
# {'n_rows': 1200,
#  'n_cols': 16,
#  'missing': 0,
#  'target_counts': {'Moderate': 743, 'Healthy': 306, 'At Risk': 151},
#  'warnings': []}

# %%
from config import (
    TARGET,
    TASK,
    TARGET_CLASSES,
    LIFESTYLE_FEATURES,
    EXCLUDED_COLUMNS,
    SEED,
    TEST_SIZE,
    DATASET_URL,
    EXPECTED_ROWS,
    EXPECTED_COLS,
)

print("TARGET:", TARGET)
print("TASK:", TASK)
print("TARGET_CLASSES:", TARGET_CLASSES)
print("SEED:", SEED)
print("TEST_SIZE:", TEST_SIZE)
print("Expected shape:", (EXPECTED_ROWS, EXPECTED_COLS))
print("Dataset URL:", DATASET_URL)
print("Lifestyle features (" + str(len(LIFESTYLE_FEATURES)) + "):")
for col in LIFESTYLE_FEATURES:
    print(" -", col)
print("Excluded columns:")
for col in EXCLUDED_COLUMNS:
    print(" -", col)
# Out:
# TARGET: digital_wellbeing_flag
# TASK: multiclass
# TARGET_CLASSES: ('Healthy', 'Moderate', 'At Risk')
# SEED: 42
# TEST_SIZE: 0.2
# Expected shape: (1200, 16)
# Dataset URL: https://www.kaggle.com/datasets/argonnxx/teen-mental-health
# Lifestyle features (9):
#  - age
#  - gender
#  - daily_social_media_hours
#  - platform_usage
#  - sleep_hours
#  - screen_time_before_sleep
#  - academic_performance
#  - physical_activity
#  - social_interaction_level
# Excluded columns:
#  - stress_level
#  - anxiety_level
#  - addiction_level
#  - mental_health_risk_score
#  - depression_label
#  - sleep_quality

# %%
assert config.TARGET == "digital_wellbeing_flag"
assert df.shape == (1200, 16)
assert validation["missing"] == 0
assert figures_dir().is_dir()
assert models_dir().is_dir()
assert metrics_dir().is_dir()

print("Phase 1 smoke tests passed.")
print("Target counts:", validation["target_counts"])
# Out:
# Phase 1 smoke tests passed.
# Target counts: {'Moderate': 743, 'Healthy': 306, 'At Risk': 151}
